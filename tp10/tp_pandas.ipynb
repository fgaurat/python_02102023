# %%
import numpy as np
import pandas as pd
from UserDao import UserDao

# %%
s = pd.Series([1,3,5,np.nan,6,8])
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
dates = pd.date_range("20231002",periods=4)
dates
# Out:
# DatetimeIndex(['2023-10-02', '2023-10-03', '2023-10-04', '2023-10-05'], dtype='datetime64[ns]', freq='D')

# %%
df2 = pd.DataFrame(
    {
        "A": 1.0,
        "B": pd.Timestamp("20130102"),
        "C": pd.Series(1, index=list(range(4)), dtype="float32"),
        "D": np.array([3] * 4, dtype="int32"),
        "E": pd.Categorical(["test", "train", "test", "train"]),
        "F": "foo",
    }
)

df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
dao = UserDao("users_db.db")
users = dao.findAll()

df_users = pd.DataFrame(users)
df_users
# Out:
#         id   first_name     last_name                       email  \
# 0        1     Etheline         Buzza             ebuzza0@com.com
# 1        2  Bartholomeo      Izacenko    bizacenko1@mediafire.com
# 2        3       Loella     Tatterton  ltatterton2@guardian.co.uk
# 3        4       Kelsey      Winfield      kwinfield3@twitpic.com
# 4        5       Hailee         Kienl     hkienl4@studiopress.com
# ...    ...          ...           ...                         ...
# 3011  3012        Gayel          Denk            gdenkrn@jugem.jp
# 3012  3013        Hagen     Spohrmann  hspohrmannro@xinhuanet.com
# 3013  3014     Carleton  Jedrachowicz   cjedrachowiczrp@topsy.com
# 3014  3015        Ddene         Brome           dbromerq@admin.ch
# 3015  3016     Ealasaid    Cunnington    ecunningtonrr@forbes.com
#
#            gender       ip_address
# 0     Genderfluid   237.157.210.81
# 1            Male   255.255.87.212
# 2          Female   177.227.166.29
# 3      Non-binary     181.45.85.41
# 4          Female  199.177.169.197
# ...           ...              ...
# 3011       Female    145.165.80.55
# 3012         Male  253.177.225.227
# 3013         Male  126.241.150.193
# 3014       Female   141.100.75.162
# 3015       Female    24.175.35.218
#
# [3016 rows x 6 columns]

# %%
df_users.head()
# Out:
#    id   first_name  last_name                       email       gender  \
# 0   1     Etheline      Buzza             ebuzza0@com.com  Genderfluid
# 1   2  Bartholomeo   Izacenko    bizacenko1@mediafire.com         Male
# 2   3       Loella  Tatterton  ltatterton2@guardian.co.uk       Female
# 3   4       Kelsey   Winfield      kwinfield3@twitpic.com   Non-binary
# 4   5       Hailee      Kienl     hkienl4@studiopress.com       Female
#
#         ip_address
# 0   237.157.210.81
# 1   255.255.87.212
# 2   177.227.166.29
# 3     181.45.85.41
# 4  199.177.169.197

# %%
df_users.tail()
# Out:
#         id first_name     last_name                       email  gender  \
# 3011  3012      Gayel          Denk            gdenkrn@jugem.jp  Female
# 3012  3013      Hagen     Spohrmann  hspohrmannro@xinhuanet.com    Male
# 3013  3014   Carleton  Jedrachowicz   cjedrachowiczrp@topsy.com    Male
# 3014  3015      Ddene         Brome           dbromerq@admin.ch  Female
# 3015  3016   Ealasaid    Cunnington    ecunningtonrr@forbes.com  Female
#
#            ip_address
# 3011    145.165.80.55
# 3012  253.177.225.227
# 3013  126.241.150.193
# 3014   141.100.75.162
# 3015    24.175.35.218

# %%
df_users.describe()
# Out:
#                 id
# count  3016.000000
# mean   1508.500000
# std     870.788532
# min       1.000000
# 25%     754.750000
# 50%    1508.500000
# 75%    2262.250000
# max    3016.000000

# %%
df_users.index
# Out:
# RangeIndex(start=0, stop=3016, step=1)

# %%
df_users.columns
# Out:
# Index(['id', 'first_name', 'last_name', 'email', 'gender', 'ip_address'], dtype='object')

# %%
df_users['first_name']
# Out:
# 0          Etheline
# 1       Bartholomeo
# 2            Loella
# 3            Kelsey
# 4            Hailee
#            ...
# 3011          Gayel
# 3012          Hagen
# 3013       Carleton
# 3014          Ddene
# 3015       Ealasaid
# Name: first_name, Length: 3016, dtype: object

# %%
df_users.iloc[412]
# Out:
# id                                413
# first_name                        Zoe
# last_name                      Yedall
# email         zyedallb0@economist.com
# gender                         Female
# ip_address            228.138.227.183
# Name: 412, dtype: object

# %%
df_users[df_users["email"].str.contains('economist.com')]
# Out:
#         id first_name    last_name                         email  gender  \
# 412    413        Zoe       Yedall       zyedallb0@economist.com  Female
# 508    509   Gabriele  Scardifield  gscardifielddo@economist.com    Male
# 1412  1413        Zoe       Yedall       zyedallb0@economist.com  Female
# 1508  1509   Gabriele  Scardifield  gscardifielddo@economist.com    Male
# 2412  2413        Zoe       Yedall       zyedallb0@economist.com  Female
# 2508  2509   Gabriele  Scardifield  gscardifielddo@economist.com    Male
#
#            ip_address
# 412   228.138.227.183
# 508    70.189.110.228
# 1412  228.138.227.183
# 1508   70.189.110.228
# 2412  228.138.227.183
# 2508   70.189.110.228

# %%
df_users['upper_last_name'] = df_users['last_name'].map(lambda v: v.upper())
df_users
# Out:
#         id   first_name     last_name                       email  \
# 0        1     Etheline         Buzza             ebuzza0@com.com
# 1        2  Bartholomeo      Izacenko    bizacenko1@mediafire.com
# 2        3       Loella     Tatterton  ltatterton2@guardian.co.uk
# 3        4       Kelsey      Winfield      kwinfield3@twitpic.com
# 4        5       Hailee         Kienl     hkienl4@studiopress.com
# ...    ...          ...           ...                         ...
# 3011  3012        Gayel          Denk            gdenkrn@jugem.jp
# 3012  3013        Hagen     Spohrmann  hspohrmannro@xinhuanet.com
# 3013  3014     Carleton  Jedrachowicz   cjedrachowiczrp@topsy.com
# 3014  3015        Ddene         Brome           dbromerq@admin.ch
# 3015  3016     Ealasaid    Cunnington    ecunningtonrr@forbes.com
#
#            gender       ip_address upper_last_name
# 0     Genderfluid   237.157.210.81           BUZZA
# 1            Male   255.255.87.212        IZACENKO
# 2          Female   177.227.166.29       TATTERTON
# 3      Non-binary     181.45.85.41        WINFIELD
# 4          Female  199.177.169.197           KIENL
# ...           ...              ...             ...
# 3011       Female    145.165.80.55            DENK
# 3012         Male  253.177.225.227       SPOHRMANN
# 3013         Male  126.241.150.193    JEDRACHOWICZ
# 3014       Female   141.100.75.162           BROME
# 3015       Female    24.175.35.218      CUNNINGTON
#
# [3016 rows x 7 columns]

# %%
df_users.to_excel("users.xlsx",index=False,engine="openpyxl")
